# %% [markdown]
# <a href="https://colab.research.google.com/github/sathwika0324/PDS-PROJECT/blob/main/Untitled0_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
# Step 2: Load the data
data = pd.read_csv('Mall_Customers.csv')
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# Step 3: Data Preprocessing
# Check for missing values
print("Missing values in each column:")
print(data.isnull().sum())
# Out:
# Missing values in each column:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# Check for duplicates
print(f"Number of duplicate rows: {data.duplicated().sum()}")
data.drop_duplicates(inplace=True)
# Out:
# Number of duplicate rows: 0

# %%
# Data Cleaning: Drop unnecessary columns
data_cleaned = data.drop(columns=['CustomerID'])

# %%
X = data_cleaned[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]  # Define the features you want to scale

# %%
# Encode categorical variables
data['Gender'] = data['Gender'].map({'Male': 0, 'Female': 1})

# %%
#Check for NaN or Infinite Values
# Select only numeric columns
numeric_data = data_cleaned.select_dtypes(include=[np.number])

# Check for infinite values in numeric columns
print(np.isinf(numeric_data).sum())  # Count of infinite values per column
# Out:
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
#Handle Infinite Values: Replace or remove
data_cleaned.replace([np.inf, -np.inf], 0, inplace=True)

# %%
# Step 4: Handling Outliers
# Boxplot for initial outlier detection
# Define features for the boxplot
features = ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %%
# Identify outliers based on IQR
Q1 = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']].quantile(0.25)
Q3 = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']].quantile(0.75)
IQR = Q3 - Q1

outliers = data[((data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']] < (Q1 - 1.5 * IQR)) |
                  (data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Create a boxplot for each feature
sns.boxplot(data=data[features], palette='Set2')

# Highlight outliers
for feature in features:
    outlier_data = outliers[feature]
    plt.scatter([features.index(feature)] * len(outlier_data),  # X positions for each feature
                outlier_data,
                color='red', marker='o', s=100, label='Outliers' if feature == features[0] else "")  # Avoid duplicate legend entries

# Set titles and labels
plt.title('Boxplot with Outliers Highlighted')
plt.xticks(ticks=range(len(features)), labels=features)
plt.legend()
plt.grid()

# Show the plot
plt.show()

# %%
# Remove outliers based on IQR
Q1 = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']].quantile(0.25)
Q3 = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']].quantile(0.75)
IQR = Q3 - Q1
data_no_outliers = data[~((data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']] < (Q1 - 1.5 * IQR)) |
                          (data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# Boxplot for outlier detection after removal
plt.figure(figsize=(10, 6))
sns.boxplot(data=data_no_outliers[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']])
plt.title('Boxplot for Outlier Detection (After Removal)')
plt.show()

# %%
# Step 5: Exploratory Data Analysis (EDA)
# Univariate Analysis
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], bins=15, kde=True)
plt.title('Distribution of Age')
plt.grid()
plt.show()

# %%
# Bivariate Analysis
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Annual Income (k$)', y='Spending Score (1-100)', hue='Gender', palette='Set1')
plt.title('Annual Income vs. Spending Score')
plt.grid()
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(data.corr(), annot=True, cmap='crest', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Step 6: Data Scaling
scaler = MinMaxScaler()
features = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]
scaled_features = scaler.fit_transform(features)

# %%
# Step 7: Clustering
# Hierarchical Clustering
# Linkage matrix using 'ward' method
linkage_matrix = linkage(scaled_features, method='ward')

# %%
# Plot Dendrogram
plt.figure(figsize=(10, 7))
plt.title("Dendrogram for Hierarchical Clustering")
plt.xlabel("Customers")
plt.ylabel("Euclidean distances")
dendrogram(linkage_matrix)
plt.show()

# %%
silhouette_scores = []
k_range = range(2, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_features)
    score = silhouette_score(scaled_features, kmeans.labels_)
    silhouette_scores.append(score)

# %%
# Plotting silhouette scores
plt.figure(figsize=(10, 6))
plt.plot(k_range, silhouette_scores, marker='o')
plt.title('Silhouette Score for Different Number of Clusters (K-Means)')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.grid()
plt.show()

# %%
# Using optimal k from the elbow method
optimal_k = 5  # Replace with your chosen k based on the Elbow Method
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
data['KMeans_Cluster'] = kmeans.fit_predict(scaled_features)

# %%
# Clustering using DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
data['DBSCAN_Cluster'] = dbscan.fit_predict(scaled_features)

# %%
# Clustering using Agglomerative Clustering
agglo = AgglomerativeClustering(n_clusters=optimal_k)
data['Agglo_Cluster'] = agglo.fit_predict(scaled_features)

# %%
# Perform K-Means clustering
kmeans = KMeans(n_clusters=3, random_state=42)  # Adjust the number of clusters as needed
kmeans_labels = kmeans.fit_predict(scaled_features)

# %%
# Step 8: Performance Evaluation
# Evaluate K-Means clustering performance
kmeans_silhouette = silhouette_score(scaled_features, data['KMeans_Cluster'])
kmeans_db_index = davies_bouldin_score(scaled_features, data['KMeans_Cluster'])
kmeans_ch_index = calinski_harabasz_score(scaled_features, data['KMeans_Cluster'])

# %%
print("\nK-Means Clustering Performance:")
print(f"Silhouette Score: {kmeans_silhouette:.4f}")
print(f"Davies-Bouldin Index: {kmeans_db_index:.4f}")
print(f"Calinski-Harabasz Index: {kmeans_ch_index:.4f}")
# Out:
# K-Means Clustering Performance:
# Silhouette Score: 0.4042
# Davies-Bouldin Index: 0.9387
# Calinski-Harabasz Index: 125.9310

# %%
# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#  K-Means Clustering
kmeans = KMeans(n_clusters=5, random_state=42)  # Choose the number of clusters
kmeans_labels = kmeans.fit_predict(X_scaled)

# %%
#  Random Forest
# Add the K-Means clusters as the target variable
data_cleaned['Cluster'] = kmeans_labels

# %%
 #Define features and target for classification
X_class = X_scaled
y_class = kmeans_labels

# %%
# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_class, y_class, test_size=0.3, random_state=42)

# %%
# Train Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predict on test set
y_pred = rf.predict(X_test)

# %%
# Accuracy of Random Forest
rf_accuracy = accuracy_score(y_test, y_pred)
print(f"Random Forest Accuracy: {rf_accuracy:.4f}")
# Out:
# Random Forest Accuracy: 1.0000

# %%
# Evaluate DBSCAN clustering performance
if -1 in data['DBSCAN_Cluster'].unique():
    filtered_dbscan = data[data['DBSCAN_Cluster'] != -1]
    dbscan_silhouette = silhouette_score(scaled_features[filtered_dbscan.index], filtered_dbscan['DBSCAN_Cluster'])
    dbscan_db_index = davies_bouldin_score(scaled_features[filtered_dbscan.index], filtered_dbscan['DBSCAN_Cluster'])
    dbscan_ch_index = calinski_harabasz_score(scaled_features[filtered_dbscan.index], filtered_dbscan['DBSCAN_Cluster'])

    print("\nDBSCAN Clustering Performance:")
    print(f"Silhouette Score: {dbscan_silhouette:.4f}")
    print(f"Davies-Bouldin Index: {dbscan_db_index:.4f}")
    print(f"Calinski-Harabasz Index: {dbscan_ch_index:.4f}")
else:
    print("\nDBSCAN produced no noise points, evaluation metrics will not include filtering.")
# Out:
# DBSCAN produced no noise points, evaluation metrics will not include filtering.

# %%
# Evaluate Agglomerative Clustering performance
agglo_silhouette = silhouette_score(scaled_features, data['Agglo_Cluster'])
print(f"\nAgglomerative Clustering Silhouette Score: {agglo_silhouette:.4f}")
# Out:
# Agglomerative Clustering Silhouette Score: 0.3955

# %%
# Step 9: Dimensionality Reduction (PCA)
pca = PCA(n_components=2)
pca_features = pca.fit_transform(scaled_features)

# %%
# Visualizing clusters in PCA space
plt.figure(figsize=(10, 6))
sns.scatterplot(x=pca_features[:, 0], y=pca_features[:, 1], hue=data['KMeans_Cluster'], palette='Set1')
plt.title('K-Means Clustering Results in PCA Space')
plt.grid()
plt.show()

# %%
# Step 10: t-SNE for Further Visualization
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
tsne_features = tsne.fit_transform(scaled_features)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=tsne_features[:, 0], y=tsne_features[:, 1], hue=data['KMeans_Cluster'], palette='Set1')
plt.title('K-Means Clustering Results in t-SNE Space')
plt.grid()
plt.show()

# %%
# Step 11: Feature Selection using Random Forest
X = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]
y = data['KMeans_Cluster']  # Assuming we want to predict the cluster

# %%
rf = RandomForestClassifier(random_state=42)
selector = RFE(rf, n_features_to_select=2)
selector = selector.fit(X, y)

print("\nSelected Features:")
print(X.columns[selector.support_])
# Out:
# Selected Features:
# Index(['Annual Income (k$)', 'Spending Score (1-100)'], dtype='object')
